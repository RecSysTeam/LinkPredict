# %%
from src.data import extract_vault, holdout
import matplotlib.pyplot as plt 
import networkx as nx

import markdown as md
from bs4 import BeautifulSoup
import PyPDF2

import io
from PIL import Image
import numpy as np

import torch
from transformers import BertTokenizer, BertModel, VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer

from tqdm.notebook import tqdm
import pickle

from scipy import sparse

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
vault = extract_vault('./vaultes/obsidian-hub/')
# vault = extract_vault('./vaultes/brain/')
# Out:
# Front matter not populated for T - Thecookiemomma's Daily Log.md: ParserError('while parsing a block mapping', <yaml._yaml.Mark object at 0x7f8081d2ce00>, 'did not find expected key', <yaml._yaml.Mark object at 0x7f8081d2cf90>)
# Front matter not populated for T - Thecookiemomma's Daily Log.md: ParserError('while parsing a block mapping', <yaml._yaml.Mark object at 0x7f8090f334f0>, 'did not find expected key', <yaml._yaml.Mark object at 0x7f8090f33b30>)
# Front matter not populated for radekkozak.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8081e6ef40>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060fe4950>)
# Front matter not populated for radekkozak.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8060e931d0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060e93b80>)
# Front matter not populated for kepano.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8060bf17c0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060bf1f90>)
# Front matter not populated for kepano.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f80c384c8b0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f80c384c310>)
# Front matter not populated for jaynguyens.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8091090900>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060edbd10>)
# Front matter not populated for jaynguyens.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8060ecfef0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060ecfbd0>)
# Front matter not populated for beaussan.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f808208ab80>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f808208ad10>)
# Front matter not populated for beaussan.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8090fe74a0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8090fe7d60>)
# Front matter not populated for gavinmn.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f80c368a950>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f80c368aae0>)
# Front matter not populated for gavinmn.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f80c377e5e0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f80c377ea90>)
# Front matter not populated for T - Thecookiemomma's Daily Log.md: ParserError('while parsing a block mapping', <yaml._yaml.Mark object at 0x7f80c3574810>, 'did not find expected key', <yaml._yaml.Mark object at 0x7f80c3574860>)
# Front matter not populated for radekkozak.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f80911db950>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8081ddad60>)
# Front matter not populated for kepano.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8060b7d5e0>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060b7d180>)
# Front matter not populated for jaynguyens.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f80b0b45c20>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f80b0b458b0>)
# Front matter not populated for beaussan.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f809170c860>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8081f06860>)
# Front matter not populated for gavinmn.md: ScannerError('while scanning for the next token', <yaml._yaml.Mark object at 0x7f8060b9a810>, 'found character that cannot start any token', <yaml._yaml.Mark object at 0x7f8060b9aef0>)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4874 entries,  to Everblush
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rel_filepath      2413 non-null   object
#  1   abs_filepath      2413 non-null   object
#  2   file_exists       4874 non-null   bool
#  3   n_backlinks       4874 non-null   int64
#  4   n_wikilinks       2337 non-null   float64
#  5   n_tags            2337 non-null   float64
#  6   n_embedded_files  2337 non-null   float64
#  7   modified_time     2413 non-null   datetime64[ns]
#  8   graph_category    4874 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 347.5+ KB
# None

# %%
#df = brain_vault.get_all_file_metadata()
df = vault.get_all_file_metadata()
df
# Out:
#                                                                       rel_filepath  \
# file
#                                                                                NaN
# dgarrett                                         01 - Community/People/dgarrett.md
# Digital garden                                     05 - Concepts/Digital garden.md
# SuperChamp234                               01 - Community/People/SuperChamp234.md
# Obsidian community plugins             05 - Concepts/Obsidian community plugins.md
# ...                                                                            ...
# css-obsidian-layout.png                                                        NaN
# 01 - Community/People/hipstersmoothie                                          NaN
# signynt                                                                        NaN
# g-bauer                                                                        NaN
# Everblush                                                                      NaN
#
#                                                                             abs_filepath  \
# file
#                                                                                      NaN
# dgarrett                               vaultes/obsidian-hub/01 - Community/People/dga...
# Digital garden                         vaultes/obsidian-hub/05 - Concepts/Digital gar...
# SuperChamp234                          vaultes/obsidian-hub/01 - Community/People/Sup...
# Obsidian community plugins             vaultes/obsidian-hub/05 - Concepts/Obsidian co...
# ...                                                                                  ...
# css-obsidian-layout.png                                                              NaN
# 01 - Community/People/hipstersmoothie                                                NaN
# signynt                                                                              NaN
# g-bauer                                                                              NaN
# Everblush                                                                            NaN
#
#                                        file_exists  n_backlinks  n_wikilinks  \
# file
#                                              False           18          NaN
# dgarrett                                      True            2          1.0
# Digital garden                                True           14          7.0
# SuperChamp234                                 True            2          1.0
# Obsidian community plugins                    True            0          0.0
# ...                                            ...          ...          ...
# css-obsidian-layout.png                      False            1          NaN
# 01 - Community/People/hipstersmoothie        False            4          NaN
# signynt                                      False            1          NaN
# g-bauer                                      False            1          NaN
# Everblush                                    False            2          NaN
#
#                                        n_tags  n_embedded_files  \
# file
#                                           NaN               NaN
# dgarrett                                  0.0               0.0
# Digital garden                            0.0               1.0
# SuperChamp234                             0.0               0.0
# Obsidian community plugins                1.0               0.0
# ...                                       ...               ...
# css-obsidian-layout.png                   NaN               NaN
# 01 - Community/People/hipstersmoothie     NaN               NaN
# signynt                                   NaN               NaN
# g-bauer                                   NaN               NaN
# Everblush                                 NaN               NaN
#
#                                                       modified_time  \
# file
#                                                                 NaT
# dgarrett                              2023-03-23 23:53:17.731308937
# Digital garden                        2023-03-23 23:53:17.879609108
# SuperChamp234                         2023-03-23 23:53:17.720331669
# Obsidian community plugins            2023-03-23 23:53:17.880585432
# ...                                                             ...
# css-obsidian-layout.png                                         NaT
# 01 - Community/People/hipstersmoothie                           NaT
# signynt                                                         NaT
# g-bauer                                                         NaT
# Everblush                                                       NaT
#
#                                       graph_category
# file
#                                          nonexistent
# dgarrett                                        note
# Digital garden                                  note
# SuperChamp234                                   note
# Obsidian community plugins                      note
# ...                                              ...
# css-obsidian-layout.png                  nonexistent
# 01 - Community/People/hipstersmoothie    nonexistent
# signynt                                  nonexistent
# g-bauer                                  nonexistent
# Everblush                                nonexistent
#
# [4874 rows x 9 columns]

# %%
df.index.value_counts()
# Out:
# Everblush                                                                                               2
# g-bauer                                                                                                 2
# signynt                                                                                                 2
# 01 - Community/People/hipstersmoothie                                                                   2
# css-obsidian-layout.png                                                                                 2
#                                                                                                        ..
# 02 - Community Expansions/02.05 All Community Expansions/Plugins/bpmn-plugin                            1
# obsidian-hover-editor                                                                                   1
# 05 - Concepts/Sherlocking                                                                               1
# 04 - Guides, Workflows, & Courses/Guides/Want some Sass with your obsidian theme‽ here's How and Why    1
# transclusions                                                                                           1
# Name: file, Length: 4869, dtype: int64

# %%
nodes_to_remove = []

for i, row in df.iterrows():
    if str(row['abs_filepath']) == 'nan' or row['n_backlinks'] == 0:
        nodes_to_remove.append(i)
nodes_to_remove
# Out:
# ['',
#  'Obsidian community plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-gist',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-image-gallery',
#  '2021-06-12 Folder Indexer, Smarter Typography, & OCR',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Tomorrow Night Bright',
#  'obsidian-drag-and-drop-blocks',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/custom-classes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-electron-window-tweaker',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-latex-environments',
#  '01 - Community/People/Bryan Jenks',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/text-progress-bar',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Prism',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/digitalgarden',
#  '01 - Community/People/xavdid',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-vim-im-switch-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/breadcrumbs',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-save-as-gist',
#  '01 - Community/Obsidian Roundup/2022-12-17 Obsidian October Winners & AI Integrations',
#  '01 - Community/People/ashwinjadhav818',
#  '00 - Contribute to the Obsidian Hub/03 Contributor Notes/03.03 Scripts and Automation/update_hub GitHub Action',
#  '01 - Community/People/Arch-Storm',
#  '01 - Community/People/NastyGamer',
#  '01 - Community/People/zacharyc',
#  '01 - Community/People/wesmoncrief',
#  '🗂️ 03.03 Scripts and Automation',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-book-search-plugin',
#  '01 - Community/People/selfire1',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/url-into-selection',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-task-collector',
#  '2021-08-21 Paid Dev Opportunities & Time Tracking with Toggl',
#  'Justin DiRose',
#  '04 - Guides, Workflows, & Courses/Community Talks/How to create your own Obsidian plugin',
#  'Button Action & Trait Templates',
#  '01 - Community/People/ArianaKhit',
#  'Origami',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-transcription',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-advanced-codeblock',
#  '01 - Community/People/ObsidianPublisher',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/copy-note',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - Author',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-autoscroll',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/WY Console',
#  '01 - Community/Obsidian Roundup/2021-07-03 Sync Updates, URI improvements, & workflows',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-apple-reminders-plugin',
#  '00 - Contribute to the Obsidian Hub/03 Contributor Notes/03.02 Design Decisions/Content Lists',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Gastown',
#  '01 - Community/People/c4ctus5',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-bellboy',
#  'T - TODO',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-https-fe_1.png',
#  '01 - Community/People/gitobsidiantutorial',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-text-format',
#  '2023-02-04 Git plugins & OCR improvements',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/google-calendar',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/cm-editor-syntax-highlight-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/better-fn',
#  '01 - Community/People/schemar',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/longform',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-incremental-writing',
#  '04 - Guides, Workflows, & Courses/for Beginners',
#  '01 - Community/Obsidian Roundup/2022-10-08 PDF Indexing & Live Preview Table Edits',
#  '01 - Community/People/mjessome',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Primary',
#  '01 - Community/People/MohrJonas',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/performance-snapshot-step1.png',
#  '01 - Community/Obsidian Roundup/2023-02-11 Natural Language Search & a New CEO',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/various-complements',
#  '01 - Community/People/moelody',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Dragon speech recognition',
#  '01 - Community/People/zjhcn',
#  '01 - Community/People/ceciliamay',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/note-folder-autorename',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-global-hotkeys',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-codeblock-labels',
#  '02 - Community Expansions/02.02 Themes by Category/🗂️ 02.02 Themes by Category',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-extra-md-commands',
#  '04 - Guides, Workflows, & Courses/Guides/Best Practices and Tips for Theme Development',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-indentation-guides',
#  '01 - Community/People/hua03',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-search-everywhere-plugin',
#  '01 - Community/Events/🗂️ Events',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-md-to-jira',
#  '02 - Community Expansions/02.02 Themes by Category/Minimalistic Themes',
#  '2022-01-01  Recipe Importing, Linking to Aliases, and Semantic Search',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/better-inline-fields',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-latex-suite',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/customizable-menu',
#  '01 - Community/People/heliostatic',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/google-photos',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-table-to-csv-exporter',
#  '02 - Community Expansions/02.01 Plugins by Category/Paid and subscription-based plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-commits',
#  '01 - Community/People/lstrzepek',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-echarts',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-task-archiver',
#  '01 - Community/People/raineszm',
#  '01 - Community/People/samuelsong70',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/todo-txt',
#  '01 - Community/People/caronchen',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-webhooks',
#  '01 - Community/People/mybuddymichael',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-file-path-to-uri',
#  '01 - Community/People/hhhapz',
#  '01 - Community/People/AnubisNekhet',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/mochi-cards-exporter',
#  '2022-03-12 Pin Preview Popups & an Intro to Dataview Guide',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-https-fe_2.png',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/local-quotes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-embedded-code-title',
#  '01 - Community/Obsidian Roundup/2022-01-29 5x8 Virtual Event, Persistent Graph Layouts, & New Category Visualizations',
#  '01 - Community/People/lanice',
#  '01 - Community/People/Braweria',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-share-as-gist',
#  '01 - Community/People/learnerfvs',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/leader-hotkeys-obsidian',
#  '01 - Community/People/artisticat1',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/csv-obsidian',
#  '04 - Guides, Workflows, & Courses/Guides/An Introduction to Dataview',
#  '01 - Community/People/valteriomon',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/linkify',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/initiative-tracker',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Dark Graphite',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/3d-graph',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-actions.png',
#  '01 - Community/People/MatthewAlner',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-quiet-outline',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/insert-unsplash-image',
#  '01 - Community/People/curio-heart',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-gallery',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-icon-swapper',
#  '02 - Community Expansions/02.01 Plugins by Category/Task management plugins',
#  '01 - Community/People/kurakart',
#  '01 - Community/People/MeepTech',
#  '01 - Community/People/kbravh',
#  '01 - Community/People/Slowbad',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Calibre',
#  '01 - Community/People/xldenis',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins to manage internal and external links',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - CSS Snippet',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-rewarder',
#  '01 - Community/People/bennyxguo',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-card-view-mode',
#  '🗂️ Weekly notes',
#  '01 - Community/People/tresselteam',
#  '03 - Showcases & Templates/Vaults/🗂️ Vaults',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/garble-text',
#  '01 - Community/People/TechTheAwesome',
#  '05 - Concepts/PARA',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/homepage',
#  'Links',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Harmonic',
#  '03 - Showcases & Templates/Dashboards/Wordcount Dashboard',
#  '01 - Community/Obsidian Roundup/2021-09-18 Better Workspace Features & LaTeX-style PDF export styling',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/obsidian_ia',
#  '01 - Community/Contributing to the Community/Volunteer Plugin Doc Writers',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/maximise-active-pane-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/waypoint',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-plugin-tagged-documents-viewer',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/mx-bili-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-comments',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/typing-transformer-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/webpage-html-export',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/TTRPG_Campaign_Mgt_ - _Where_To_Begin.png',
#  '01 - Community/People/Nigecat',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/short-internal-links-to-headings',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Red Graphite',
#  '01 - Community/People/BumbrT',
#  '01 - Community/People/luke-rmaki',
#  '03 - Showcases & Templates/Templates/Plugin-specific templates/Dataview templates/Project Cards',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - MOCs',
#  '02 - Community Expansions/02.01 Plugins by Category/Spaced Repetition Plugins',
#  '01 - Community/People/AlexW00',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/media-extended',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-mindmap-nextgen',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github create pull request.png',
#  '01 - Community/People/wei2912',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/squiggle',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/todoist-text',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Aqua',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-markmind',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Dayspring',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/quick-explorer',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-https-fe_5.png',
#  'Plugins to export Markdown content',
#  '01 - Community/Obsidian Roundup/2023-01-21 More LLM Integrations & Sample Notes for Cooking, Workouts, etc.',
#  '01 - Community/People/monesga',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/dangerzone-writing-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-mathjax-wikilinks',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github compare forks.png',
#  'Obsidian Starter Templates',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-siteswap',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/repeat-plugin',
#  '01 - Community/People/bgoosman',
#  '03 - Showcases & Templates/Templates/Plugin-specific templates/Dataview templates/Locale Dataview Query Template',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/sliding-panes-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Obsidian Boom',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-furigana',
#  '01 - Community/People/cakechaser',
#  '01 - Community/People/nekoshita',
#  '01 - Community/People/charliecm',
#  '01 - Community/People/darlal',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/calendar',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-import-json',
#  '2021-08-28 20 Plugins & Several Philosophies of Tags',
#  'Scripts for Maintenance',
#  '04 - Guides, Workflows, & Courses/Guides/Controlling Obsidian via a Third-party App',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/qmd-as-md-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/file-forgetting-curve-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Silence',
#  'Fanfiction',
#  '01 - Community/People/vanadium23',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/Mara_FolderColor2.png',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/settings-search',
#  '01 - Community/People/nothingislost',
#  '01 - Community/People/tillahoffmann',
#  '01 - Community/People/liamcain',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-toggle-meta-yaml-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/icalBuddy',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dynamic-toc',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins for vault statistics',
#  '2022-10-01 Pandoc, Happiness, & Dataview Tricks',
#  "03 - Showcases & Templates/Vaults/SlRvb's Journaling Setup",
#  '01 - Community/People/erichalldev',
#  '01 - Community/People/Xallt',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Hazel',
#  '01 - Community/Obsidian Roundup/2021-05-08 Templater, Syncthing & Requested Plugins',
#  '01 - Community/People/st3v3nmw',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-awesome-flashcard',
#  '01 - Community/People/Daeik',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-metatable',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Zutilo',
#  '01 - Community/People/mProjectsCode',
#  '04 - Guides, Workflows, & Courses/Guides/HIPAA Requirements and Obsidian Primer',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/revealjs',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Research Rabbit',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/simple-note-review',
#  '01 - Community/Obsidian Roundup/2022-05-28 Demo Vaults, PKM History, & an editable graph view',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/contextual-comments',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-wordnet-plugin',
#  '01 - Community/People/gracejoseph1236',
#  '01 - Community/People/sbquinlan',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-daily-named-folder',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-daily-notes-opener',
#  '01 - Community/People/mrglitchbyte',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-cursor-location-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/DDC_Folder_Maker',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/emoji-shortcodes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/copy-as-latex',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Creature',
#  '01 - Community/Obsidian Roundup/2022-10-29 Supercharged tags & a new Zotero integration',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/status-bar-quote',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/copy-as-html',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-youglish-plugin',
#  '01 - Community/People/isaaclyman',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/restore-tab-key',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Golden Book',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/list-style',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/better-pdf-plugin',
#  '01 - Community/People/elliotboyd',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-kindle-export',
#  '01 - Community/People/RafaelGB',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/cmdr',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/VSCode Guide - Folding and Regions.gif',
#  '01 - Community/People/graydon',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/LCC_Folder_Maker',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-zoom',
#  '01 - Community/People/gtg922r',
#  '03 - Showcases & Templates/Templates/Weekly notes/🗂️ Weekly notes',
#  '01 - Community/People/filipesilva',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-regex-replace',
#  '01 - Community/People/alvaro-cas',
#  '01 - Community/People/flolu',
#  '01 - Community/People/danyim',
#  'T - Auxiliary Tool Category',
#  '01 - Community/People/THeK3nger',
#  '01 - Community/Obsidian Roundup/2021-06-05 New Themes, Kanban Updates & Dropbox Backups',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-https-fe_6.png',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/Mara_FolderColor.png',
#  '01 - Community/People/GuangluWu',
#  '05 - Concepts/Obsidian community themes',
#  'Discussion Needed',
#  '04 - Guides, Workflows, & Courses/Guides/Using Obsidian as a TTRPG Campaign Manager',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/folder-note-plugin',
#  '01 - Community/People/kometenstaub',
#  '01 - Community/People/msrch',
#  '01 - Community/Obsidian Roundup/2022-10-15 Obsidian Out of Beta, Obsidian October Extended',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-reveal-active-file',
#  '01 - Community/Obsidian Roundup/2022-09-17 Dataview Example Vault, Book Club, & Ecosystem Stats',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Nightingale',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-rant',
#  '01 - Community/People/kkzzhizhou',
#  '01 - Community/Video Channels/Community Talks',
#  'for Beginners',
#  'T - Blog posts',
#  '01 - Community/People/Wittionary',
#  'Dreams',
#  '01 - Community/People/DubininDmitry',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/deepl',
#  '01 - Community/People/fzdwx',
#  '01 - Community/People/lynchjames',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Tokyo Night',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-embedded-note-titles',
#  '01 - Community/People/martin-jw',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-living-graph',
#  '01 - Community/People/Ellpeck',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/graph-analysis',
#  '01 - Community/People/kuchejak',
#  'Obsidian-Dice-Roller-Tables-Collection',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/oz-clear-unused-images',
#  '01 - Community/Obsidian Roundup/2021-10-23 New Calendar & Code Renders in Edit Mode',
#  '2021-11-27  Rearrange Outlines and Integrate your Content Discovery Process',
#  '<% tp.file.creation_date("YYYY")%>',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Moonlight',
#  '01 - Community/Obsidian Roundup/2021-06-19 QuickAdd, a plugin updates channel, & new guides',
#  '02 - Community Expansions/02.04 Auxiliary Tools by Category/OCR Tools',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/format-hotkeys-obsidian',
#  '01 - Community/Obsidian Roundup/2022-06-11 API changes & new public vaults',
#  '01 - Community/People/claremacrae',
#  'Obsidian2Mkdocs',
#  '01 - Community/People/tth05',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/California Coast',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-contacts',
#  '01 - Community/People/pulsovi',
#  '01 - Community/People/dybrawin',
#  '01 - Community/People/cmoskvitin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-asciidoc-blocks',
#  "03 - Showcases & Templates/Templates/Daily notes/T - Thecookiemomma's Daily Log",
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/advanced-paste',
#  '04 - Guides, Workflows, & Courses/Guides/🗂️ Guides',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Shimmering Obsidian',
#  '01 - Community/People/dpickett',
#  '01 - Community/People/munach',
#  '01 - Community/People/TilBlechschmidt',
#  '01 - Community/Obsidian Roundup/2022-08-06 Quick Share & a new Minimalist Theme',
#  '2022-02-26 Documentation efforts, Mobile Live Preview, & Improved Startup Time',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-day-planner',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-local-rest-api',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-new-note-new-window',
#  '2022-09-24 Community Contest & Spaced Repetition Improvements',
#  '01 - Community/People/Sekund',
#  '01 - Community/People/ocapraro',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/youhavebeenstaring-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-paste-as-html',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/literate-haskell',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/cryptsidian',
#  '01 - Community/Events/Obsidian October 2021',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Al Dente',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-tweaks',
#  'YT - Dataview Plugin - How to Use this Powerful Obsidian Plugin (With Examples)',
#  '01 - Community/People/marcoluzi',
#  '05 - Concepts/Websites',
#  '01 - Community/People/metawops',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/link-exploder',
#  '01 - Community/People/gavvvr',
#  '01 - Community/People/MajorEnkidu',
#  '04 - Guides, Workflows, & Courses/Community Talks/Create Your Own Obsidian Plugin - How To Get Started',
#  '2022-07-02 Bionic Reading, Improved Popout Windows, & Better Databases',
#  '04 - Guides, Workflows, & Courses/Community Talks/Zettelkasten 101',
#  '02 - Community Expansions/02.04 Auxiliary Tools by Category/MacOS Tools',
#  '00 - Contribute to the Obsidian Hub/Obsidian Settings for Contributors',
#  '01 - Community/People/dbarenholz',
#  '01 - Community/People/maldonacho',
#  '01 - Community/People/bLaCkwEw',
#  '01 - Community/People/ArtexJay',
#  '2022-01-08  New Guides and API Charts',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-edit-file.png',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Rosé Pine Moon',
#  '01 - Community/People/dartungar',
#  '05 - Concepts/Zettelkasten',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-collapse-all-plugin',
#  '01 - Community/Obsidian Roundup/2022-06-18 Breaking Changes & Dataview API Upgrades',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-read-it-later',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-vim-multibyte-char-search',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/phone-to-roam-to-obsidian',
#  '01 - Community/People/kenlim',
#  '01 - Community/People/BambusControl',
#  '01 - Community/People/JichouP',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/lumberjack-obsidian',
#  '01 - Community/People/adifyr',
#  '2022-07-09 Dashboards & Tips for Students, Studying & Sales',
#  '01 - Community/People/yo-goto',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/kill-and-yank',
#  '01 - Community/People/shabegom',
#  '01 - Community/People/SkepticMystic',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/console',
#  '04 - Guides, Workflows, & Courses/Community Talks/Obsidian 101',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/scrybble.ink',
#  '01 - Community/Events/Obsidian Community Talks',
#  '01 - Community/People/yeeshue99',
#  '01 - Community/Obsidian Roundup/2023-01-07 AI, Canvas, Terminal & Tasks plugins',
#  '01 - Community/Obsidian Roundup/2022-06-25 Popping out Plugins & Calendar Imports',
#  '01 - Community/People/RuslanGagushin',
#  '01 - Community/People/subframe7536',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/o2',
#  '2022-07-16 Roadmap updates, OCR & Podcast notes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/improved-vimcursor',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/file-tree-alternative',
#  'Plugins to convert content into markdown',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-advanced-new-file',
#  '01 - Community/People/juracy',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-prozen',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-google-tasks',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dynbedded',
#  '06 - Inbox/🗂️ 06 - Inbox',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Obuntu',
#  '01 - Community/People/gavinmn',
#  '01 - Community/People/tim-hub',
#  '05 - Concepts/Obsidian Core Plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/new-tab-default-page',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/callout-manager',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/zotero-link',
#  '01 - Community/Obsidian Roundup/2021-10-02 Premade Concept Hierarchies & a Virtual Community Meeting Space',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github.dev switch to fork.png',
#  '🗂️ Literature notes',
#  '01 - Community/People/firinael',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-orthography',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Nebula',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/quote-share',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-etherpad-plugin',
#  '01 - Community/People/blacksmithgu',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/tag-page-preview',
#  '02 - Community Expansions/02.01 Plugins by Category/Dictionary and Spellchecking Plugins',
#  '01 - Community/People/caro401',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/text-extractor',
#  '01 - Community/People/hydescarf',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-https-fe_3.png',
#  '01 - Community/People/callumhackett',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-custom-file-extensions-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Tesseract',
#  'harmtemolder',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-editor-web.png',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins with custom codeblock syntax',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-heading-shifter',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Maple',
#  '01 - Community/People/Pr0dt0s',
#  '01 - Community/People/lyonsquark',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/things-logbook',
#  '2021-07-31 Leveraging Graphs, a QuickAdd guide, & Plugin Changelogs',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-open-in-other-editor',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-fullscreen-plugin',
#  '01 - Community/People/pmbauer',
#  '00 - Contribute to the Obsidian Hub/03 Contributor Notes/03.03 Scripts and Automation/Testing Python Code with Approval Tests',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-golinks',
#  '04 - Guides, Workflows, & Courses/Guides/How to release a new version of your plugin',
#  '01 - Community/People/vslinko',
#  '01 - Community/People/SimeonLukas',
#  'Mado Miniflow',
#  '01 - Community/People/denisoed',
#  '2021-05-29 Tricks for Mobile, Quick Capture, & Outliner Interoperability',
#  '01 - Community/People/reuseman',
#  'Warmth',
#  '01 - Community/People/vrtmrz',
#  '04 - Guides, Workflows, & Courses/Community Talks/Knowledge Organization, Cataloguing and Classification in Obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-expand-bullet',
#  '02 - Community Expansions/02.05 All Community Expansions/CSS Snippets/Center Tables',
#  '01 - Community/Events/Obsidian October 2022',
#  '01 - Community/People/Nilahn',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-acme_2.png',
#  '01 - Community/People/ptrsvltns',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-text-expander-js',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Hipstersmoothie',
#  '01 - Community/People/nguyenvanduocit',
#  '🗂️ Dataview templates',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/no-empty-windows',
#  'Ukiyo',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-audio-player',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/snippets',
#  '01 - Community/People/pyrochlore',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-note-autocreator',
#  '02 - Community Expansions/02.04 Auxiliary Tools by Category/🗂️ 02.04 Auxiliary Tools by Category',
#  '01 - Community/People/hush-hush',
#  '01 - Community/People/ganesshkumar',
#  '01 - Community/Video Channels/🗂️ Video Channels',
#  '00 - Contribute to the Obsidian Hub/Contributing templates to the community vault',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-smart-typography',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-things3-sync',
#  'Checklist for reviewing Pull Requests',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Ayu Mirage',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github.dev editor version control.png',
#  '01 - Community/Obsidian Roundup/2021-08-14 Highlights Syncing & a Minimal Editor GUI',
#  '01 - Community/People/stargrey',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/canvas-css-class',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Dark Graphite Pie',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/mrj-text-expand',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-folder-focus-mode',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-file-color',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/sQdthOne',
#  '01 - Community/People/willasm',
#  '01 - Community/Obsidian Roundup/2021-08-07 Translations, Longform Export Tools, & Tips for Mobile',
#  '05 - Concepts/Spaced repetition',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Purple Aurora',
#  '01 - Community/People/hrenaud',
#  '05 - Concepts/Obsidian queries',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-stopwatch-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-telegraph-publish',
#  '01 - Community/Contributing to the Community/Plugins seeking help',
#  'Life Disciplines Projects',
#  '06 - Inbox/HAProxy',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-wikipedia',
#  '01 - Community/People/jvsteiner',
#  '01 - Community/People/LastKnightCoder',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/hotkey-helper',
#  'Firefox extensions',
#  '01 - Community/People/beet',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-jsonifier',
#  '01 - Community/People/9r0x',
#  '01 - Community/People/mimishahzad',
#  '02 - Community Expansions/02.02 Themes by Category/Customizable Themes',
#  '01 - Community/Obsidian Roundup/2021-07-10 New UUID plugin, better mindmaps, & a user survey',
#  '01 - Community/People/moolmanruan',
#  '02 - Community Expansions/02.05 All Community Expansions/CSS Snippets/Alternate Admonitions (SlRvb)',
#  '01 - Community/People/stbowers',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/macOS-keyboard-nav-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-canvas-conversation',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-weread-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/review-obsidian',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins for Security and Privacy',
#  '01 - Community/People/ravimashru',
#  '04 - Guides, Workflows, & Courses/for Academic Writing',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/theme-submission-add-comma.png',
#  '03 - Showcases & Templates/Plugin Showcases/Tooltips for Literature Notes with Supercharged Links',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/chronology',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-excel-to-markdown-table',
#  '01 - Community/People/jarodise',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-tidy-footnotes',
#  '01 - Community/People/schlundd',
#  'wei2912',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-media-db-plugin',
#  '03 - Showcases & Templates/Plugin Showcases/Breadcrumbs for Comparative Law',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/braincache',
#  '01 - Community/People/zhaohongxuan',
#  'OGKevin',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Clair de Lune',
#  '01 - Community/People/dvcrn',
#  'Sherlocking',
#  '01 - Community/People/jgchristopher',
#  '01 - Community/People/samepage-network',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Agora',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-icons-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/todoist-completed-tasks-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-audio-notes',
#  '01 - Community/People/jgauth',
#  '03 - Showcases & Templates/Vaults/Template_Hub',
#  '01 - Community/Obsidian Roundup/2022-09-03 Tabs and a new Default Theme',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/netwik',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-query2table',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/callout-integrator',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/consistent-attachments-and-links',
#  'for Creative Writing',
#  '01 - Community/People/alangrainger',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-frontmatter-tag-suggest',
#  '2021-10-02  Premade Concept Hierarchies & a Virtual Community Meeting Space',
#  '01 - Community/People/nqthqn',
#  '01 - Community/People/anoopkcn',
#  '01 - Community/People/No3371',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/ytranscript',
#  '01 - Community/People/kevboh',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-review-notes-plugin',
#  '01 - Community/People/cloudhao1999',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/file-explorer-markdown-titles',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Comfort color dark',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-smart-links',
#  '🗂️ Plugin-specific templates',
#  '02 - Community Expansions/02.03 CSS Snippets by Category/🗂️ 02.03 CSS Snippets by Category',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/neo4j-graph-view',
#  'Plugins for collaboration',
#  '03 - Showcases & Templates/Plugin Showcases/Graph view',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-find-and-replace-in-selection',
#  '01 - Community/Obsidian Roundup/2021-05-15 Better Footnotes, Plugin Synergy, & an Electron Update',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/css-snippets',
#  '01 - Community/People/Ledaryy',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Material Ocean',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-languagetool-plugin',
#  '01 - Community/People/piotryordanov',
#  '01 - Community/People/FlorianWoelki',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Wikipedia',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/open-weather',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-plotly',
#  '01 - Community/People/geoffreysflaminglasersword',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Anki',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-chessboard',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/uri-commands',
#  '01 - Community/People/aitaDev',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-plugin-update-tracker',
#  '01 - Community/People/obsidian-ezs',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Dracula + LYT',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Dropbox',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Wombat',
#  '2022-05-28 Demo Vaults, PKM History, & an editable graph view',
#  '04 - Guides, Workflows, & Courses/Community Talks/Deep Learning on Networks',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/ITS Theme',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Mdnotes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/heycalmdown-navigate-cursor-history',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-overdue',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-tikzjax',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-toggle-list',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-auto-link-title',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/random-structural-diary-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/WilcoxOne',
#  '01 - Community/People/AndreasStandar',
#  '01 - Community/People/hedonihilist',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-drag-n-drop-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/ledger-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-readwise',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/samepage',
#  '01 - Community/People/lukeleppan',
#  '01 - Community/People/olrenso',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/flashcards-obsidian',
#  '01 - Community/People/chrisgrieser',
#  'Deep Thoughts',
#  '01 - Community/People/Jopp-gh',
#  '01 - Community/People/modality',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-vocabulary-view',
#  'Plugins to convert content into Markdown',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-kroki',
#  '01 - Community/People/Automatt',
#  '01 - Community/People/AmadeusWM',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-excalidraw-plugin',
#  '01 - Community/People/zhouhua',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-extract-pdf-annotations',
#  '01 - Community/People/zhaoshenzhai',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/weekly-review',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-actions-running.png',
#  '2021-07-24 Showcases, Link Cards, & Better Tablet Toolbars',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/code-block-plugin',
#  '01 - Community/People/nyable',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/mysnippets-plugin',
#  '01 - Community/Obsidian Roundup/2022-02-26 Documentation efforts, Mobile Live Preview, & Improved Startup Time',
#  '01 - Community/People/tomzorz',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/pdf-to-markdown-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/quote-of-the-day',
#  '01 - Community/People/ConnorMeyers',
#  '01 - Community/People/Zachatoo',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-notes-from-template',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/code-block-copy',
#  '01 - Community/People/rcvd',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dialogue-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-wrap-with-shortcuts',
#  '01 - Community/People/mcndt',
#  '01 - Community/People/eth-p',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-lock-screen-plugin',
#  '01 - Community/People/luigman',
#  '03 - Showcases & Templates/Vaults/PARA Starter Kit',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-compare-changes.png',
#  '01 - Community/People/dogwaddle',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-relativenumber',
#  '01 - Community/People/davidgolding',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-note-content-pusher',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-open-pr.png',
#  '04 - Guides, Workflows, & Courses/Guides/How to find examples of Jest-based plugin tests',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-quran-lookup',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/simple-dice-roller',
#  '01 - Community/People/noonesimg',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins for Diagrams',
#  '01 - Community/People/dy-sh',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/chord-lyrics',
#  '01 - Community/Obsidian Roundup/2022-12-10 Whiteboard Canvas for Mindmaps, & a personal note',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-chat-view',
#  '2023-01-14 Use Cases for Canvas & New Courses and Sample Vaults',
#  '01 - Community/People/bramses',
#  'Dayspring',
#  '01 - Community/Obsidian Roundup/2021-08-28 20 Plugins & Several Philosophies of Tags',
#  '01 - Community/People/SmortApp',
#  '01 - Community/People/felixchenier',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-matrix',
#  '01 - Community/Obsidian Roundup/2021-12-03 Obsidian October winners and a ton of TTRPG stuff',
#  '01 - Community/People/larslockefeer',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/link-info-server',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Aura',
#  '01 - Community/People/friebetill',
#  '04 - Guides, Workflows, & Courses/Guides/Why automate tests for plugins',
#  '01 - Community/Obsidian Roundup/2022-01-22 API improvements for devs & Reference vs. Reflection usage',
#  '01 - Community/People/basham',
#  '01 - Community/People/MichalBures',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/actions-uri',
#  '01 - Community/People/brandonkboswell',
#  '01 - Community/People/avirut',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-oura-plugin',
#  '01 - Community/People/jsartelle',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-to-notion',
#  '04 - Guides, Workflows, & Courses/Guides/How to debug why Obsidian is running slowly',
#  '04 - Guides, Workflows, & Courses/Guides/YT - Intro to Dataview Plugin',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - Website',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/Syncthing',
#  '2022-06-25 Popping out Plugins & Calendar Imports',
#  '01 - Community/People/yalvhe2009',
#  '2022-01-15  Dataview Optimizations, Live Preview for Mobile, and Community Talks',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Lizardmen Zettelkasten',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/home-tab',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Obsidian Windows 98 Edition',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/nldates-obsidian',
#  '01 - Community/People/izumin5210',
#  'bri',
#  '06 - Inbox/Obsidian2Mkdocs',
#  'Cat',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/editor-commands-remap',
#  '01 - Community/Obsidian Roundup/2021-11-13 WYSIWYG (called Live Preview) is HERE',
#  '01 - Community/People/shaggyfeng',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Obsidianotion',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/smort-obsidian',
#  '01 - Community/Obsidian Roundup/2022-02-05 Better Android performance & custom sorting of files',
#  '01 - Community/People/Johnny',
#  '01 - Community/People/ChopTV',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-front-matter-title-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-local-images-plus',
#  '2021-10-15  More WYSIWYG Functionality & Some Really Nice Documentation',
#  '01 - Community/People/TClark1011',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/mathpad',
#  '01 - Community/People/argenos',
#  '03 - Showcases & Templates/Templates/🗂️ Templates',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-image-auto-upload-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-to-anki-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-budget-wysiwyg',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/tag-summary-plugin',
#  "03 - Showcases & Templates/Vaults/SlRvb's MediaDB Setup",
# ...
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-relative-find',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Cybertron',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/auto-glossary',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/better-word-count',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Typewriter',
#  '01 - Community/People/bencodezen',
#  'Minimalistic Themes',
#  '01 - Community/🗂️ 01 - Community',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/excalibrain',
#  '01 - Community/People/nikbrunner',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-edits-on-your-fork.png',
#  '02 - Community Expansions/02.01 Plugins by Category/Markdown formatting plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Typomagical',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/image-captions',
#  '01 - Community/People/Make-md',
#  '01 - Community/Obsidian Roundup/2022-07-30 Obsidian Shirts, Grouped Tasks & 1-min Guides',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-link-opener',
#  '2023-01-28 Plugin graphs & academic tools',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-release-timeline',
#  '01 - Community/People/YukiGasai',
#  '01 - Community/People/aleksey-rezvov',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/recent-files-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/text-snippets-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/stenography-obsidian',
#  '01 - Community/Video Channels/YouTube Channels',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Ono Sendai',
#  '2022-03-05 Dashboards, Dataview Tips, & global publish graphs',
#  '2023-01-07 AI, Canvas, Terminal & Tasks plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dice-roller',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github-fork-notice.png',
#  '01 - Community/People/nuthrash',
#  '01 - Community/People/renehernandez',
#  '01 - Community/People/zorazrr',
#  '00 - Contribute to the Obsidian Hub/Tag glossary',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/update-time-on-edit',
#  '01 - Community/People/Basil-Mori',
#  '01 - Community/People/colineckert',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/sekund',
#  'fantasycalendar',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-task-progress-bar',
#  '01 - Community/People/krios2146',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/apple-books-highlights',
#  '01 - Community/People/k4a-dev',
#  '02 - Community Expansions/02.01 Plugins by Category/Mathjax and LaTeX Plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-scroll-offset',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-focus-mode',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-amazingmarvin-plugin',
#  'Project Cards',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-toggle-case',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/simple-note-quiz',
#  '02 - Community Expansions/02.01 Plugins by Category/Unlisted plugins',
#  '02 - Community Expansions/🗂️ 02 - Community Expansions',
#  '01 - Community/People/Taitava',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian42-brat',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - GitHub Repository',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-project-garden',
#  '01 - Community/People/kepano',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/PLN',
#  '01 - Community/People/Cleoche',
#  '01 - Community/People/conneroisu',
#  'T - Author',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-hyphenation',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dirtreeist',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-icon-folder',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/luhman',
#  '01 - Community/People/Pseudonium',
#  '01 - Community/People/weichenw',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-badge',
#  '02 - Community Expansions/02.01 Plugins by Category/Side bar plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/highlightr-plugin',
#  '03 - Showcases & Templates/Templates/Monthly notes/🗂️ Monthly notes',
#  '01 - Community/People/leenattress',
#  '01 - Community/People/rwirdemann',
#  '01 - Community/People/erykwalder',
#  '01 - Community/People/SimonTC',
#  '01 - Community/Obsidian Roundup/2021-11-20 Live Preview Updates, Fancy Checkboxes and Tips for Devs',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Obsidianite',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-emoji-toolbar',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-itinerary',
#  '2022-10-22 Improved note relationship sensing & Catppuccinos!',
#  '01 - Community/People/tokenshift',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Dracula for Obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-min3ditorhotkeys-plugin',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins to navigate notes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-new-bullet-with-time',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-custom-frames',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Firefly',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-local-images',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/completed-area',
#  '01 - Community/People/zcysxy',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/github.dev editor commit changes.png',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Suddha',
#  '01 - Community/People/victorb',
#  '01 - Community/People/lucas-fern',
#  '01 - Community/People/samwarnick',
#  '01 - Community/People/bingryan',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-memos',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/linked-data-helper',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-copy-block-link',
#  '01 - Community/People/yaleiyale',
#  '01 - Community/People/mnowotnik',
#  'Anthony Gold',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/note-refactor-obsidian',
#  '04 - Guides, Workflows, & Courses/Community Talks/YT - Pandoc and Obsidian - Create slideshows, PDFs and Word documents',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/smart-random-note',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-card-view-switcher-plugin',
#  '01 - Community/People/Edo78',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-linter',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-extlnkhelper-plugin',
#  'tcmmichaelb139',
#  '01 - Community/People/aidenlx',
#  '04 - Guides, Workflows, & Courses/for Specific Professions',
#  'Notation 2',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/tasks-packrat-plugin',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins with custom views',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/VSCode',
#  '2021-06-19 QuickAdd, a plugin updates channel, & new guides',
#  '04 - Guides, Workflows, & Courses/Guides/Using Pandoc inside Obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-rich-links',
#  '01 - Community/People/joeyuping',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/🗂️ Themes',
#  '01 - Community/People/nadavspi',
#  '02 - Community Expansions/02.05 All Community Expansions/CSS Snippets/All Alternate Themes (ITS Theme)',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Yin and Yang',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Micro Mike',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/metaedit',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/publish-pfsense-acme_4.png',
#  '01 - Community/People/kenset',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Carnelian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-plugin-dynamodb',
#  "04 - Guides, Workflows, & Courses/Guides/Want some Sass with your obsidian theme‽ here's How and Why",
#  '05 - Concepts/Sherlocking',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/bpmn-plugin',
#  '01 - Community/People/holubj',
#  '01 - Community/People/cassidoo',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-topic-linking',
#  '01 - Community/People/michaeladams',
#  '01 - Community/People/kmsk99',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/japanese-word-splitter',
#  '00 - Contribute to the Obsidian Hub/03 Contributor Notes/03.02 Design Decisions/Content Plugins',
#  '01 - Community/Obsidian Roundup/2022-12-03 An academic vault tour & weekly review templates',
#  'Pamela Wang',
#  '01 - Community/People/shakedlokits',
#  '01 - Community/Contributing to the Community/🗂️ Contributing to the Community',
#  '01 - Community/People/turulix',
#  '02 - Community Expansions/02.05 All Community Expansions/CSS Snippets/Alternate Checkboxes (SlRvb)',
#  '01 - Community/People/samlewis0602',
#  '2021-05-22 Templater Scripts, Sync workarounds & Obsidian for Work',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian42-strange-new-worlds',
#  '01 - Community/People/Bluemoondragon07',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/microblog-publish-plugin',
#  '02 - Community Expansions/02.01 Plugins by Category/Vim-related Plugins',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-hide-sidebars-when-narrow',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-dynamic-highlights',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-folder-index',
#  'tresselteam',
#  '2022-01-22 API improvements for devs & Reference vs. Reflection usage',
#  '00 - Contribute to the Obsidian Hub/02 Attachments/TTRPG_Campaign_Mgt_- _FacebookTTRPGUserGroup.png',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-highlightpublicnotes-plugin',
#  '01 - Community/People/brianpetro',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Shimmering Focus',
#  '00 - Contribute to the Obsidian Hub/03 Contributor Notes/03.02 Design Decisions/Content Comments',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Sanguine',
#  '01 - Community/People/natelandau',
#  'hub.yaml proposal for themes',
#  '01 - Community/People/KjellConnelly',
#  '01 - Community/People/FireIsGood',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/aosr',
#  '05 - Concepts/HTML',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-kindle-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-admonition',
#  '2022-06-11 API changes & new public vaults',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/link-nodes-in-canvas',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-export-to-tex',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/table-extended',
#  '02 - Community Expansions/02.01 Plugins by Category/Plugins for Chess',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/canvas-filter',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/open-related-url',
#  '02 - Community Expansions/02.05 All Community Expansions/Auxiliary Tools/MGit',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/map-of-content',
#  '01 - Community/Obsidian Roundup/2022-01-08 New Guides and API Charts',
#  '00 - Contribute to the Obsidian Hub/01 Templates/T - Templates',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-fuzzytag',
#  'for Academic Writing',
#  '01 - Community/People/JulesGuesnon',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Big Sur Aesthetic',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/s3-image-uploader',
#  '01 - Community/People/tansongchen',
#  '02 - Community Expansions/02.05 All Community Expansions/CSS Snippets/Asides (SlRvb)',
#  'masonlr',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Catppuccin',
#  '2022-03-19 Better Citations Workflows & Native Callout Boxes',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-plugin-groups',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/writing',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-gpt',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-list-modified',
#  'Obsidian Hub',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Ultra Lobster',
#  '2022-09-03 Tabs and a new Default Theme',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-auto-split',
#  '01 - Community/People/George-debug',
#  '01 - Community/People/ryjjin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-code-preview',
#  '01 - Community/People/mirnovov',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/hard-breaks',
#  '01 - Community/People/Meikul',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/execute-code',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Aurora',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-daily-stats',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/Sparkling Wisdom',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/emoji-magic',
#  '01 - Community/People/inouetakuya',
#  '2021-12-18  Gems of the Year, Vim Mode, and RTL Support',
#  '01 - Community/People/anstosa',
#  '01 - Community/People/hans',
#  '01 - Community/People/CyberT17',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/ozanshare-publish',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-another-quick-switcher',
#  'Shiba Inu',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/cycle-in-sidebar',
#  '01 - Community/Obsidian Roundup/2021-07-31 Leveraging Graphs, a QuickAdd guide, & Plugin Changelogs',
#  '03 - Showcases & Templates/Templates/Projects/🗂️ Projects',
#  '01 - Community/People/supercip971',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/simple-time-tracker',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/hidden-folder-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/ava',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/macro-plugin',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/templater-obsidian',
#  '02 - Community Expansions/02.05 All Community Expansions/Themes/iA Writer',
#  '01 - Community/People/paddan',
#  '01 - Community/People/trenta3',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-simple-mention',
#  '02 - Community Expansions/02.01 Plugins by Category/🗂️ 02.01 Plugins by Category',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/key-promoter',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/auto-moc',
#  '02 - Community Expansions/02.05 All Community Expansions/Plugins/obsidian-title-serial-number-plugin',
#  '01 - Community/People/ntawileh',
#  ...]

# %%
len(vault.graph.nodes)
# Out:
# 4869

# %%
vault.graph.remove_nodes_from(nodes_to_remove)

# %%
len(vault.graph.nodes)
# Out:
# 2220

# %%
df["abs_filepath"].apply(lambda x: str(x).split('.')[-1]).value_counts()
# Out:
# nan    2461
# md     2337
# png      64
# gif      11
# svg       1
# Name: abs_filepath, dtype: int64

# %%
df = df[~df["abs_filepath"].isna()]

# %%
df["abs_filepath"].apply(lambda x: str(x).split('.')[-1]).value_counts()
# Out:
# md     2337
# png      64
# gif      11
# svg       1
# Name: abs_filepath, dtype: int64

# %%
def get_text_from_html(html):
    soup = BeautifulSoup(html, features="html.parser")

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

def get_text_from_markdown(filepath):
    with open(filepath, 'r') as f:
        text = f.read()
        html = md.markdown(text)
        text = get_text_from_html(html)
    return text

def get_text_from_pdf(filepath):
    with open(filepath, 'rb') as f:
        pdfReader = PyPDF2.PdfReader(f)
        text = ""
        
        for page in pdfReader.pages:
            text += page.extract_text()
            all_images.extend(page.images)
    return text


def get_images_from_pdf(filepath):
    with open(filepath, 'rb') as f:
        pdfReader = PyPDF2.PdfReader(f)
        images = []
        
        for page in pdfReader.pages:
            for image_file in page.images:
                images.append(Image.open(io.BytesIO(image_file.data)))
    return images

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer_bert = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model_bert = BertModel.from_pretrained("bert-base-multilingual-cased")

model_bert.to(device)

1
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 1

# %%
model_i2t = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
feature_extractor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer_i2t = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

model_i2t.to(device)

1
# Out:
# 1

# %%
@torch.no_grad()
def encode_text(text):
    encoded_input = tokenizer_bert(text, truncation=True, return_tensors='pt')
    output = model_bert(**encoded_input)
    return output.pooler_output.cpu().numpy()[0]

# %%
def image_to_text(image):
    if image.mode != "RGB":
        image = image.convert(mode="RGB")
    
    pixel_values = feature_extractor(images=[image], return_tensors="pt").pixel_values
    pixel_values = pixel_values.to(device)

    gen_kwargs = {"max_length": 256, "num_beams": 4}
    output_ids = model_i2t.generate(pixel_values, **gen_kwargs)

    preds = tokenizer_i2t.batch_decode(output_ids, skip_special_tokens=True)
    preds = [pred.strip() for pred in preds]
    return preds[0]

# %%
# embeddings = []

# for path in tqdm(df["abs_filepath"]):
#     extension = str(path).split('.')[-1]
#     if extension == 'md':
#         text = get_text_from_markdown(path)
#         embeddings.append(encode_text(text))
#     elif extension == 'pdf':
#         text = get_text_from_pdf(path)
#         images = get_images_from_pdf(path)
#         for image in tqdm(images, desc='images', leave=False):
#             text += " "
#             text += image_to_text(image)
#         embeddings.append(encode_text(text))
#     elif extension in {'jpeg', 'gif', 'png'}:
#         image = Image.open(path)
#         text = image_to_text(image)
#         embeddings.append(encode_text(text))
#     else:
#         # embeddings.append(np.random.rand(768))
#         1/0

# %%
embeddings = []

for text in tqdm(vault.graph.nodes):
    embeddings.append(encode_text(text))
# Out:
#   0%|          | 0/2220 [00:00<?, ?it/s]

# %%
emb_dict = {}

for file, emb in zip(vault.graph.nodes, embeddings):
    emb_dict[file] = emb

with open("obsidian_embeddings.pkl", 'wb') as f:
    pickle.dump(emb_dict, f)

# %% [markdown]
# # LightFM part

# %%
from lfm import build_lfm_model
from evaluation import topn_recommendations
# Out:
# /Users/avzelentsov/PycharmProjects/LinkPredict/.rec_sys_proj_venv/lib/python3.9/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
len(vault.graph.nodes)
# Out:
# 2220

# %%
modified_graph, deleted_edges = holdout(vault.graph, alpha=0.2)

# %%
modified_graph

# %%
del_edges = []

for edge in deleted_edges:
    ind0 = list(vault.graph.nodes).index(edge[0])
    ind1 = list(vault.graph.nodes).index(edge[1])
    del_edges.append((ind0, ind1))

del_edges
# Out:
# [(2144, 547),
#  (2138, 1718),
#  (2137, 1055),
#  (2136, 1055),
#  (2136, 1406),
#  (2136, 1406),
#  (2135, 1050),
#  (2133, 1915),
#  (2133, 1915),
#  (2130, 227),
#  (2130, 227),
#  (2129, 1105),
#  (2126, 2132),
#  (2125, 1040),
#  (2123, 1055),
#  (2122, 950),
#  (2121, 1749),
#  (2120, 1055),
#  (2118, 1055),
#  (2118, 1658),
#  (2116, 1568),
#  (2116, 807),
#  (2116, 403),
#  (2113, 106),
#  (2113, 839),
#  (2112, 1670),
#  (2112, 1473),
#  (2112, 1898),
#  (2112, 993),
#  (2112, 961),
#  (2112, 1125),
#  (2112, 1051),
#  (2112, 1397),
#  (2109, 1673),
#  (2109, 339),
#  (2108, 880),
#  (2107, 1529),
#  (2106, 211),
#  (2100, 1831),
#  (2098, 636),
#  (2097, 1168),
#  (2096, 1888),
#  (2096, 1040),
#  (2093, 1751),
#  (2091, 524),
#  (2089, 727),
#  (2089, 507),
#  (2089, 786),
#  (2087, 723),
#  (2086, 666),
#  (2082, 1040),
#  (2082, 979),
#  (2082, 1758),
#  (2082, 524),
#  (2079, 106),
#  (2077, 565),
#  (2068, 1744),
#  (2067, 1664),
#  (2066, 1055),
#  (2065, 2005),
#  (2064, 192),
#  (2063, 784),
#  (2061, 890),
#  (2059, 1535),
#  (2056, 1135),
#  (2055, 292),
#  (2054, 1457),
#  (2054, 1597),
#  (2054, 2009),
#  (2054, 381),
#  (2054, 155),
#  (2052, 1055),
#  (2052, 723),
#  (2051, 1055),
#  (2050, 723),
#  (2050, 723),
#  (2048, 760),
#  (2047, 333),
#  (2047, 723),
#  (2046, 1863),
#  (2046, 777),
#  (2043, 128),
#  (2032, 1372),
#  (2030, 1054),
#  (2028, 1556),
#  (2027, 1055),
#  (2027, 1632),
#  (2026, 73),
#  (2026, 891),
#  (2024, 1752),
#  (2024, 788),
#  (2023, 1289),
#  (2022, 333),
#  (2022, 66),
#  (2020, 84),
#  (2019, 1055),
#  (2017, 1055),
#  (2017, 757),
#  (2015, 106),
#  (2014, 2103),
#  (2014, 2103),
#  (2011, 635),
#  (2008, 333),
#  (2008, 705),
#  (586, 461),
#  (586, 470),
#  (586, 767),
#  (586, 534),
#  (586, 518),
#  (586, 1729),
#  (586, 1692),
#  (586, 1029),
#  (586, 1433),
#  (586, 351),
#  (586, 1822),
#  (586, 1096),
#  (586, 1075),
#  (586, 1094),
#  ...]

# %%
train_matrix = nx.adjacency_matrix(modified_graph)
train_matrix = train_matrix
train_matrix.shape
# Out:
# (2220, 2220)

# %%
train_matrix.sum()
# Out:
# 5574

# %%
data_description = dict(
    n_users = train_matrix.shape[0],
    n_items = train_matrix.shape[1],
    # user_features = ... skip for now, will be defined later
    # item_features = None # compound features are not present in the dataset
)
data_description
# Out:
# {'n_users': 2220, 'n_items': 2220}

# %%
with open("obsidian_embeddings.pkl", 'rb') as f:
    emb_dict = pickle.load(f)

# %%
data_description["user_features"] = sparse.csr_matrix([emb_dict[file] for file in vault.graph.nodes])
data_description["item_features"] = sparse.csr_matrix([emb_dict[file] for file in vault.graph.nodes])

# %%
holdout_data_description = dict(
    users = [de_[0] for de_ in del_edges],
    n_items = train_matrix.shape[1],
    # user_features = ... skip for now, will be defined later
    # item_features = None # compound features are not present in the dataset
)

# %%
holdout_data_description["user_features"] = sparse.csr_matrix([emb_dict[file] for file in vault.graph.nodes])
holdout_data_description["item_features"] = sparse.csr_matrix([emb_dict[file] for file in vault.graph.nodes])

# %%
lfm_config = dict(
    no_components = 256,
    loss = 'warp',
    max_sampled = 1,
    max_epochs = 30,
    learning_schedule = 'adagrad',
    user_alpha = 1e-3,
    item_alpha = 1e-3,
    random_state = 7032023
)

# %%
topn = 5

# %%
lfm_model = build_lfm_model(
    lfm_config,
    train_matrix,
    data_description,
    iterator = tqdm
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# your code here
def cartesian_product(x, y):
    return np.transpose([np.tile(x, len(y)), np.repeat(y, len(x))])

def lightfm_scoring(model, data, data_description, item_bias=True):
    users = np.unique(data_description['users'])
    items = np.arange(data_description['n_items'])
    
    user_item_pairs = cartesian_product(users, items)
    
    if item_bias is False:
        cur_biases = lfm_model.item_biases.copy()

        lfm_model.item_biases *= 0
    
    predictions = model.predict(
                                user_ids=user_item_pairs[:, 0],
                                item_ids=user_item_pairs[:, 1],
                                user_features=data_description['user_features'],
                                item_features=data_description['item_features'],
                               )
    scores = predictions.reshape(len(items), len(users))
    
    if item_bias is False:
        lfm_model.item_biases[:] = cur_biases
    
    return scores.T, users

# %%
lfm_scores, test_users = lightfm_scoring(lfm_model, None, holdout_data_description, item_bias=False)
lfm_recs = topn_recommendations(lfm_scores, topn=topn)

# %%
def recall(lfm_recs, users, del_edges, holdout_data_description):
    
    edges_dict = {}
    
    for edge in del_edges:
        edges_dict[edge[0]] = edges_dict.get(edge[0], set())
        edges_dict[edge[0]].add(edge[1])
    
    metric = 0
    
    for i, rec in enumerate(lfm_recs):
        metric += len(set(rec) & edges_dict[users[i]]) / len(edges_dict[users[i]])
    
    return metric / len(users)

# %%
recall(lfm_recs, test_users, del_edges, holdout_data_description)
# Out:
# 0.16942180830422973
